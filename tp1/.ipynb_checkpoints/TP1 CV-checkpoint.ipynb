# %% [markdown]
# # Vision par ordinateur - TP1
#
# ## 3. Détection de peau
#
# ### 3.2. Construction d'une base d'exemples peau - non-peau
#
# On crée une base d'images, dont voici un extrait.

# %%
import cv2
import numpy as np

import os

from IPython.display import Image

import matplotlib.pyplot as plt


def get_images(directory):
    result = []
    for f in os.listdir(directory):
        if f.endswith(".jpg") or f.endswith(".png"):
            result.append(directory + "/" + f)

    return result

Image("skin/1.png")

# %%
Image("skin/10.png")

# %%
Image("notskin/20.png")

# %%
Image("notskin/3.png")

# %% [markdown]
# ## 3.3 - Une méthode simple
#
# On construit une fonction d'après [Vezhnevets et al] pour classifier un pixel

# %%
def img_skin_naive(img):
    """
    Use simple classifier to detect skin
    """
    skin_ratio = 0
    height, width, depth = img.shape

    for col in img:
        for pixel in col:
            skin_ratio += 1 if is_skin_naive(pixel) else 0

    skin_ratio /= float(height * width)

    return skin_ratio


def is_skin_naive(pixel):
    """
    Simple classifier: return true if the pixel verifies a set of color constraints
    """
    b, g, r = pixel

    return (
        r > 95
        and g > 40
        and b > 20
        and max([r, g, b]) - min([r, g, b]) > 15
        and abs(int(r) - int(g)) > 15
        and r > g
        and r > b
    )

# %% [markdown]
# On l'applique sur notre base de donnée d'images

# %%
print "Skin " + "=" * 70

for i in get_images("skin"):
    img = cv2.imread(i)
    print "{} \t\t {:.02f}%".format(i, (img_skin_naive(img) * 100))

print "\nNot Skin " + "=" * 70

for i in get_images("notskin"):
    img = cv2.imread(i)
    print "{} \t\t {:0.2f}%".format(i, (img_skin_naive(img) * 100))
# Out:
# Skin ======================================================================
# skin/0.png 		 99.25%
# skin/1.png 		 99.19%
# skin/10.png 		 100.00%
# skin/11.png 		 100.00%
# skin/12.png 		 93.93%
# skin/13.png 		 85.73%
# skin/14.png 		 100.00%
# skin/15.png 		 99.86%
# skin/16.png 		 99.52%
# skin/17.png 		 0.00%
# skin/18.png 		 0.00%
# skin/19.png 		 100.00%
# skin/2.png 		 97.94%
# skin/20.png 		 76.33%
# skin/21.png 		 31.44%
# skin/22.png 		 100.00%
# skin/23.png 		 99.85%
# skin/24.png 		 100.00%
# skin/25.png 		 80.37%
# skin/26.png 		 0.00%
# skin/27.png 		 100.00%
# skin/28.png 		 99.88%
# skin/29.png 		 92.48%
# skin/3.png 		 93.11%
# skin/30.png 		 100.00%
# skin/31.png 		 100.00%
# skin/32.png 		 100.00%
# skin/33.png 		 16.27%
# skin/34.png 		 100.00%
# skin/35.png 		 100.00%
# skin/36.png 		 86.71%
# skin/37.png 		 99.13%
# skin/38.png 		 91.41%
# skin/39.png 		 95.13%
# skin/4.png 		 73.54%
# skin/40.png 		 100.00%
